# %%
from VideoToAudio import convert
from Diarization import diarize_audio
from ASR import generate_transcript
from ScrapYT import get_video

# %%
video_url = "https://www.youtube.com/watch?v=25WmRh95luE"
output_folder = "inputs"
get_video(video_url, output_folder)
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=25WmRh95luE
# [youtube] 25WmRh95luE: Downloading webpage
# [youtube] 25WmRh95luE: Downloading tv client config
# [youtube] 25WmRh95luE: Downloading player 69f581a5
# [youtube] 25WmRh95luE: Downloading tv player API JSON
# [youtube] 25WmRh95luE: Downloading ios player API JSON
# [youtube] 25WmRh95luE: Downloading m3u8 information
# WARNING: ffmpeg not found. The downloaded format may not be the best available. Installing ffmpeg is strongly recommended: https://github.com/yt-dlp/yt-dlp#dependencies
# [info] 25WmRh95luE: Downloading 1 format(s): 18
# [download] Destination: inputs\Nikhil Explores What’s Brewing in the Craft Beverage Industry with Rahul, Matt, Aneesh & Adithya.mp4
# [download] 100% of    6.18MiB in 00:00:04 at 1.39MiB/s

# %%
VIDEO_PATH = "inputs/videoplayback.mp4"  
OUTPUT_FORMAT = "wav"
OUTPUT_PATH = "outputs"
convert(VIDEO_PATH, OUTPUT_FORMAT, OUTPUT_PATH)
# Out:
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'isom', 'minor_version': '512', 'compatible_brands': 'isomiso2avc1mp41', 'encoder': 'Lavf61.7.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 44100, 'bitrate': 127, 'metadata': {'Metadata': '', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'video', 'language': None, 'default': True, 'size': [640, 360], 'bitrate': 1361, 'fps': 30.0, 'codec_name': 'h264', 'profile': '(High)', 'metadata': {'Metadata': '', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]', 'encoder': 'Lavc61.19.100 libx264'}}], 'input_number': 0}], 'duration': 298.17, 'bitrate': 1498, 'start': 0.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 0, 'audio_fps': 44100, 'audio_bitrate': 127, 'default_video_input_number': 0, 'default_video_stream_number': 1, 'video_codec_name': 'h264', 'video_profile': '(High)', 'video_size': [640, 360], 'video_bitrate': 1361, 'video_fps': 30.0, 'video_duration': 298.17, 'video_n_frames': 8945}
# d:\Karya\myenv\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i inputs/videoplayback.mp4 -loglevel error -f image2pipe -vf scale=640:360 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# MoviePy - Writing audio in outputs\videoplayback.wav
# MoviePy - Done.
# Conversion complete. Audio saved at: outputs\videoplayback.wav
# 'outputs\\videoplayback.wav'

# %%
file_path = "outputs/videoplayback.wav"
diarize_audio(file_path)
# Out:
# INFO:speechbrain.utils.quirks:Applied quirks (see `speechbrain.utils.quirks`): [allow_tf32, disable_jit_profiling]
# INFO:speechbrain.utils.quirks:Excluded quirks specified by the `SB_DISABLE_QUIRKS` environment (comma-separated list): []
# C:\Users\anipr\AppData\Local\Programs\Python\Python312\Lib\inspect.py:1001: UserWarning: Module 'speechbrain.pretrained' was deprecated, redirecting to 'speechbrain.inference'. Please update your script. This is a change from SpeechBrain 1.0. See: https://github.com/speechbrain/speechbrain/releases/tag/v1.0.0
#   if ismodule(module) and hasattr(module, '__file__'):
# d:\Karya\myenv\Lib\site-packages\pyannote\audio\models\blocks\pooling.py:104: UserWarning: std(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\aten\src\ATen\native\ReduceOps.cpp:1831.)
#   std = sequences.std(dim=-1, correction=1)
# Total speakers: 5
# Speech duration: 199.0s
# Speaker distribution:
# [('SPEAKER_03', 75.38062500000004), ('SPEAKER_04', 66.55500000000004), ('SPEAKER_00', 32.02874999999999), ('SPEAKER_01', 16.368750000000006), ('SPEAKER_02', 9.348749999999995)]
# Speaker SPEAKER_03 spoke from 0.0s to 0.6s
# Speaker SPEAKER_03 spoke from 1.2s to 5.5s
# Speaker SPEAKER_04 spoke from 5.9s to 8.4s
# Speaker SPEAKER_04 spoke from 16.0s to 18.6s
# Speaker SPEAKER_04 spoke from 19.4s to 20.2s
# Speaker SPEAKER_04 spoke from 22.9s to 24.3s
# Speaker SPEAKER_04 spoke from 30.7s to 31.5s
# Speaker SPEAKER_04 spoke from 34.8s to 38.0s
# Speaker SPEAKER_00 spoke from 35.4s to 35.5s
# Speaker SPEAKER_04 spoke from 39.9s to 40.7s
# Speaker SPEAKER_04 spoke from 45.1s to 47.0s
# Speaker SPEAKER_03 spoke from 47.0s to 48.0s
# Speaker SPEAKER_04 spoke from 48.0s to 48.3s
# Speaker SPEAKER_04 spoke from 49.1s to 50.9s
# Speaker SPEAKER_03 spoke from 55.0s to 56.2s
# Speaker SPEAKER_03 spoke from 57.7s to 59.0s
# Speaker SPEAKER_03 spoke from 59.5s to 64.4s
# Speaker SPEAKER_04 spoke from 69.0s to 69.0s
# Speaker SPEAKER_03 spoke from 69.0s to 69.5s
# Speaker SPEAKER_03 spoke from 71.7s to 75.2s
# Speaker SPEAKER_03 spoke from 75.6s to 75.6s
# Speaker SPEAKER_04 spoke from 75.6s to 75.6s
# Speaker SPEAKER_03 spoke from 75.6s to 75.6s
# Speaker SPEAKER_04 spoke from 75.6s to 75.8s
# Speaker SPEAKER_03 spoke from 75.8s to 75.9s
# Speaker SPEAKER_04 spoke from 75.9s to 75.9s
# Speaker SPEAKER_03 spoke from 75.9s to 76.0s
# Speaker SPEAKER_04 spoke from 76.0s to 76.5s
# Speaker SPEAKER_03 spoke from 76.5s to 76.6s
# Speaker SPEAKER_04 spoke from 76.6s to 76.8s
# Speaker SPEAKER_03 spoke from 76.8s to 77.0s
# Speaker SPEAKER_04 spoke from 77.0s to 84.1s
# Speaker SPEAKER_03 spoke from 84.3s to 90.8s
# Speaker SPEAKER_04 spoke from 90.8s to 94.3s
# Speaker SPEAKER_03 spoke from 94.0s to 94.1s
# Speaker SPEAKER_03 spoke from 94.3s to 94.3s
# Speaker SPEAKER_04 spoke from 94.3s to 96.3s
# Speaker SPEAKER_04 spoke from 96.5s to 97.7s
# Speaker SPEAKER_04 spoke from 98.0s to 98.5s
# Speaker SPEAKER_04 spoke from 99.1s to 101.5s
# Speaker SPEAKER_04 spoke from 102.1s to 106.9s
# Speaker SPEAKER_03 spoke from 107.1s to 117.0s
# Speaker SPEAKER_04 spoke from 117.0s to 118.1s
# Speaker SPEAKER_04 spoke from 118.6s to 120.5s
# Speaker SPEAKER_03 spoke from 122.9s to 122.9s
# Speaker SPEAKER_02 spoke from 122.9s to 126.2s
# Speaker SPEAKER_02 spoke from 126.5s to 132.4s
# Speaker SPEAKER_04 spoke from 139.9s to 144.4s
# Speaker SPEAKER_01 spoke from 155.0s to 156.0s
# Speaker SPEAKER_01 spoke from 157.1s to 160.0s
# Speaker SPEAKER_01 spoke from 160.3s to 163.3s
# Speaker SPEAKER_01 spoke from 163.9s to 165.9s
# Speaker SPEAKER_01 spoke from 166.6s to 168.6s
# Speaker SPEAKER_01 spoke from 169.4s to 171.6s
# Speaker SPEAKER_01 spoke from 172.4s to 173.1s
# Speaker SPEAKER_01 spoke from 173.8s to 174.2s
# Speaker SPEAKER_01 spoke from 174.9s to 177.0s
# Speaker SPEAKER_00 spoke from 177.9s to 183.4s
# Speaker SPEAKER_00 spoke from 183.7s to 186.6s
# Speaker SPEAKER_03 spoke from 186.8s to 189.1s
# Speaker SPEAKER_00 spoke from 189.3s to 192.1s
# Speaker SPEAKER_03 spoke from 192.4s to 193.3s
# Speaker SPEAKER_03 spoke from 193.7s to 195.9s
# Speaker SPEAKER_03 spoke from 196.1s to 197.4s
# Speaker SPEAKER_03 spoke from 197.9s to 198.9s
# Speaker SPEAKER_03 spoke from 199.0s to 199.9s
# Speaker SPEAKER_03 spoke from 200.0s to 205.0s
# Speaker SPEAKER_00 spoke from 205.2s to 211.7s
# Speaker SPEAKER_03 spoke from 211.8s to 214.5s
# Speaker SPEAKER_03 spoke from 215.3s to 218.5s
# Speaker SPEAKER_00 spoke from 218.8s to 227.0s
# Speaker SPEAKER_03 spoke from 227.0s to 229.6s
# Speaker SPEAKER_03 spoke from 230.8s to 232.6s
# Speaker SPEAKER_04 spoke from 232.6s to 232.6s
# Speaker SPEAKER_00 spoke from 233.2s to 239.2s
# Speaker SPEAKER_04 spoke from 239.2s to 240.9s
# Speaker SPEAKER_04 spoke from 252.9s to 252.9s
# Speaker SPEAKER_03 spoke from 252.9s to 254.6s
# Speaker SPEAKER_03 spoke from 255.2s to 257.3s
# Speaker SPEAKER_03 spoke from 258.2s to 261.5s
# Speaker SPEAKER_04 spoke from 260.4s to 260.8s
# Speaker SPEAKER_04 spoke from 261.6s to 264.8s
# Speaker SPEAKER_04 spoke from 265.2s to 267.1s
# Speaker SPEAKER_04 spoke from 267.6s to 271.9s
# Speaker SPEAKER_03 spoke from 272.3s to 272.3s
# Speaker SPEAKER_04 spoke from 272.3s to 272.3s
# Speaker SPEAKER_03 spoke from 272.3s to 274.3s
# Speaker SPEAKER_03 spoke from 274.5s to 276.2s
# Speaker SPEAKER_03 spoke from 276.5s to 279.2s
# Speaker SPEAKER_03 spoke from 279.6s to 280.4s
# Speaker SPEAKER_03 spoke from 280.8s to 281.9s
# Speaker SPEAKER_04 spoke from 284.0s to 284.3s
# Speaker SPEAKER_04 spoke from 285.1s to 286.3s
# Speaker SPEAKER_04 spoke from 287.1s to 289.8s
# Speaker SPEAKER_04 spoke from 290.0s to 292.5s
# Speaker SPEAKER_03 spoke from 292.8s to 294.5s
# Speaker SPEAKER_04 spoke from 296.1s to 296.9s
# Speaker SPEAKER_04 spoke from 297.1s to 298.2s

# %%
file_path = "outputs/videoplayback.wav"
transcript = generate_transcript(file_path)
print(transcript)
# Out:
# INFO:speechbrain.utils.quirks:Applied quirks (see `speechbrain.utils.quirks`): [disable_jit_profiling, allow_tf32]
# INFO:speechbrain.utils.quirks:Excluded quirks specified by the `SB_DISABLE_QUIRKS` environment (comma-separated list): []
# C:\Users\anipr\AppData\Local\Programs\Python\Python312\Lib\inspect.py:1001: UserWarning: Module 'speechbrain.pretrained' was deprecated, redirecting to 'speechbrain.inference'. Please update your script. This is a change from SpeechBrain 1.0. See: https://github.com/speechbrain/speechbrain/releases/tag/v1.0.0
#   if ismodule(module) and hasattr(module, '__file__'):
# d:\Karya\myenv\Lib\site-packages\pyannote\audio\models\blocks\pooling.py:104: UserWarning: std(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\aten\src\ATen\native\ReduceOps.cpp:1831.)
#   std = sequences.std(dim=-1, correction=1)
# Device set to use cpu
# d:\Karya\myenv\Lib\site-packages\transformers\models\whisper\generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Due to a bug fix in https://github.com/huggingface/transformers/pull/28687 transcription using a multilingual Whisper will default to language detection followed by transcription instead of translation to English.This might be a breaking change for your use case. If you want to instead always translate your audio to English, make sure to pass `language='en'`.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# [{'speaker': 'SPEAKER_03', 'start': 0.03096875, 'end': 0.63846875, 'text': ' qualquer'}, {'speaker': 'SPEAKER_03', 'start': 1.1953437500000001, 'end': 5.464718750000001, 'text': ' समाच के हित्में हम और एक बहुत अच्छो काम कर वे आये हैं का तमाई अनुमती है?'}, {'speaker': 'SPEAKER_04', 'start': 5.920343750000001, 'end': 8.384093750000002, 'text': ' हाँ हाँ समाच के हितमें जू काम होए वो करो'}, {'speaker': 'SPEAKER_04', 'start': 16.04534375, 'end': 18.559718750000002, 'text': ' पानी से मिझ्जोले, जेबार मनो'}, {'speaker': 'SPEAKER_04', 'start': 19.35284375, 'end': 20.21346875, 'text': '看了一天'}, {'speaker': 'SPEAKER_04', 'start': 22.89659375, 'end': 24.33096875, 'text': ' अहाँ, अब बैठ गए'}, {'speaker': 'SPEAKER_04', 'start': 30.65909375, 'end': 31.45221875, 'text': 'แม่ฮาลี่'}, {'speaker': 'SPEAKER_04', 'start': 34.77659375, 'end': 38.016593750000006, 'text': ' और दो मिनेट रुख जाया जरकें तो पहले आई गए'}, {'speaker': 'SPEAKER_00', 'start': 35.36721875, 'end': 35.51909375, 'text': " I'm out of here."}, {'speaker': 'SPEAKER_04', 'start': 39.85596875, 'end': 40.73346875, 'text': ' जा रहा हैं मम्मी?'}, {'speaker': 'SPEAKER_04', 'start': 45.087218750000005, 'end': 47.02784375, 'text': ' लेट हो जाते आर तुम्हारे चक्कर में कुछ...'}, {'speaker': 'SPEAKER_03', 'start': 47.02784375, 'end': 47.97284375, 'text': ' आज तो क्या करते हैं?'}, {'speaker': 'SPEAKER_04', 'start': 47.97284375, 'end': 48.32721875, 'text': ' पर इसलिए आपको प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर पर पर प'}, {'speaker': 'SPEAKER_04', 'start': 49.06971875, 'end': 50.94284375, 'text': ' ये तो अब तग्यार होने में टेम लग जा न?'}, {'speaker': 'SPEAKER_03', 'start': 55.04346875, 'end': 56.22471875, 'text': ' बसका रहा हूँ रही?'}, {'speaker': 'SPEAKER_03', 'start': 57.67596875, 'end': 59.025968750000004, 'text': ' आमें तो कच्छी निंगे सारो'}, {'speaker': 'SPEAKER_03', 'start': 59.46471875, 'end': 64.40909375, 'text': ' अरे नहीं दे काछु, भोध दुरगंद दायक थी जे? उठारी जीता ना, टायर मायर में तो नहीं छाबो काछु.'}, {'speaker': 'SPEAKER_04', 'start': 69.01596875, 'end': 69.03284375, 'text': ' you'}, {'speaker': 'SPEAKER_03', 'start': 69.03284375, 'end': 69.50534375000001, 'text': ' behind.'}, {'speaker': 'SPEAKER_03', 'start': 71.66534375, 'end': 75.17534375000001, 'text': ' आथू! दारे बसेला आदमी!'}, {'speaker': 'SPEAKER_03', 'start': 75.56346875, 'end': 75.58034375000001, 'text': ' you'}, {'speaker': 'SPEAKER_04', 'start': 75.58034375000001, 'end': 75.59721875000001, 'text': ' you'}, {'speaker': 'SPEAKER_03', 'start': 75.59721875000001, 'end': 75.63096875000001, 'text': ' So,'}, {'speaker': 'SPEAKER_04', 'start': 75.63096875000001, 'end': 75.81659375000001, 'text': ' 동네에.'}, {'speaker': 'SPEAKER_03', 'start': 75.81659375000001, 'end': 75.90096875, 'text': ' you'}, {'speaker': 'SPEAKER_04', 'start': 75.90096875, 'end': 75.91784375, 'text': ' you'}, {'speaker': 'SPEAKER_03', 'start': 75.91784375, 'end': 75.96846875, 'text': ' you'}, {'speaker': 'SPEAKER_04', 'start': 75.96846875, 'end': 76.49159375, 'text': ' Friendly now.'}, {'speaker': 'SPEAKER_03', 'start': 76.49159375, 'end': 76.55909375, 'text': ' you'}, {'speaker': 'SPEAKER_04', 'start': 76.55909375, 'end': 76.77846875, 'text': ' you'}, {'speaker': 'SPEAKER_03', 'start': 76.77846875, 'end': 76.96409375, 'text': ' Fuck.'}, {'speaker': 'SPEAKER_04', 'start': 76.96409375, 'end': 84.05159375000001, 'text': ' जब कि कल हमने समझा के कही थी तुमसे अरे तो तुम देखने था दिन पर दिन थंड बढ़ता ही जा रही और ददधा हम आदमी आए हमें थंड लगा थे'}, {'speaker': 'SPEAKER_03', 'start': 84.32159375, 'end': 90.80159375000001, 'text': ' अच्छा माने तू आदमी आई इसने तोई थंड लग रही और बाकी के जोन थंड में नहा रहा है वेका खच्चर है'},  ...

# %%
transcript
# Out:
# [{'speaker': 'SPEAKER_03',
#   'start': 0.03096875,
#   'end': 0.63846875,
#   'text': ' qualquer'},
#  {'speaker': 'SPEAKER_03',
#   'start': 1.1953437500000001,
#   'end': 5.464718750000001,
#   'text': ' समाच के हित्में हम और एक बहुत अच्छो काम कर वे आये हैं का तमाई अनुमती है?'},
#  {'speaker': 'SPEAKER_04',
#   'start': 5.920343750000001,
#   'end': 8.384093750000002,
#   'text': ' हाँ हाँ समाच के हितमें जू काम होए वो करो'},
#  {'speaker': 'SPEAKER_04',
#   'start': 16.04534375,
#   'end': 18.559718750000002,
#   'text': ' पानी से मिझ्जोले, जेबार मनो'},
#  {'speaker': 'SPEAKER_04',
#   'start': 19.35284375,
#   'end': 20.21346875,
#   'text': '看了一天'},
#  {'speaker': 'SPEAKER_04',
#   'start': 22.89659375,
#   'end': 24.33096875,
#   'text': ' अहाँ, अब बैठ गए'},
#  {'speaker': 'SPEAKER_04',
#   'start': 30.65909375,
#   'end': 31.45221875,
#   'text': 'แม่ฮาลี่'},
#  {'speaker': 'SPEAKER_04',
#   'start': 34.77659375,
#   'end': 38.016593750000006,
#   'text': ' और दो मिनेट रुख जाया जरकें तो पहले आई गए'},
#  {'speaker': 'SPEAKER_00',
#   'start': 35.36721875,
#   'end': 35.51909375,
#   'text': " I'm out of here."},
#  {'speaker': 'SPEAKER_04',
#   'start': 39.85596875,
#   'end': 40.73346875,
#   'text': ' जा रहा हैं मम्मी?'},
#  {'speaker': 'SPEAKER_04',
#   'start': 45.087218750000005,
#   'end': 47.02784375,
#   'text': ' लेट हो जाते आर तुम्हारे चक्कर में कुछ...'},
#  {'speaker': 'SPEAKER_03',
#   'start': 47.02784375,
#   'end': 47.97284375,
#   'text': ' आज तो क्या करते हैं?'},
#  {'speaker': 'SPEAKER_04',
#   'start': 47.97284375,
#   'end': 48.32721875,
#   'text': ' पर इसलिए आपको प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर प्रस्तुत्र पर पर पर प'},
#  {'speaker': 'SPEAKER_04',
#   'start': 49.06971875,
#   'end': 50.94284375,
#   'text': ' ये तो अब तग्यार होने में टेम लग जा न?'},
#  {'speaker': 'SPEAKER_03',
#   'start': 55.04346875,
#   'end': 56.22471875,
#   'text': ' बसका रहा हूँ रही?'},
#  {'speaker': 'SPEAKER_03',
#   'start': 57.67596875,
#   'end': 59.025968750000004,
#   'text': ' आमें तो कच्छी निंगे सारो'},
#  {'speaker': 'SPEAKER_03',
#   'start': 59.46471875,
#   'end': 64.40909375,
#   'text': ' अरे नहीं दे काछु, भोध दुरगंद दायक थी जे? उठारी जीता ना, टायर मायर में तो नहीं छाबो काछु.'},
#  {'speaker': 'SPEAKER_04',
#   'start': 69.01596875,
#   'end': 69.03284375,
#   'text': ' you'},
#  {'speaker': 'SPEAKER_03',
#   'start': 69.03284375,
#   'end': 69.50534375000001,
#   'text': ' behind.'},
#  {'speaker': 'SPEAKER_03',
#   'start': 71.66534375,
#   'end': 75.17534375000001,
#   'text': ' आथू! दारे बसेला आदमी!'},
#  {'speaker': 'SPEAKER_03',
#   'start': 75.56346875,
#   'end': 75.58034375000001,
#   'text': ' you'},
#  {'speaker': 'SPEAKER_04',
#   'start': 75.58034375000001,
#   'end': 75.59721875000001,
#   'text': ' you'},
#  {'speaker': 'SPEAKER_03',
#   'start': 75.59721875000001,
#   'end': 75.63096875000001,
#   'text': ' So,'},
#  {'speaker': 'SPEAKER_04',
#   'start': 75.63096875000001,
#   'end': 75.81659375000001,
#   'text': ' 동네에.'},
#  {'speaker': 'SPEAKER_03',
#   'start': 75.81659375000001,
#   'end': 75.90096875,
#   'text': ' you'},
#  {'speaker': 'SPEAKER_04',
#   'start': 75.90096875,
#   'end': 75.91784375,
#   'text': ' you'},
#  {'speaker': 'SPEAKER_03',
#   'start': 75.91784375,
#   'end': 75.96846875,
#   'text': ' you'},
#  {'speaker': 'SPEAKER_04',
#   'start': 75.96846875,
#   'end': 76.49159375,
#   'text': ' Friendly now.'},
#  {'speaker': 'SPEAKER_03',
#   'start': 76.49159375,
#   'end': 76.55909375,
#   'text': ' you'},
#  {'speaker': 'SPEAKER_04',
#   'start': 76.55909375,
#   'end': 76.77846875,
#   'text': ' you'},
#  {'speaker': 'SPEAKER_03',
#   'start': 76.77846875,
#   'end': 76.96409375,
#   'text': ' Fuck.'},
#  {'speaker': 'SPEAKER_04',
#   'start': 76.96409375,
#   'end': 84.05159375000001,
#   'text': ' जब कि कल हमने समझा के कही थी तुमसे अरे तो तुम देखने था दिन पर दिन थंड बढ़ता ही जा रही और ददधा हम आदमी आए हमें थंड लगा थे'},
#  {'speaker': 'SPEAKER_03',
#   'start': 84.32159375,
#   'end': 90.80159375000001,
#   'text': ' अच्छा माने तू आदमी आई इसने तोई थंड लग रही और बाकी के जोन थंड में नहा रहा है वेका खच्चर है'},
#  {'speaker': 'SPEAKER_04',
#   'start': 90.80159375000001,
#   'end': 94.26096875,
#   'text': ' बासी को हमें लगना है यादद ता पता बे नहीं नहारा लेकिन हम चलो'},
#  {'speaker': 'SPEAKER_03',
#   'start': 94.04159375,
#   'end': 94.14284375000001,
#   'text': " I'm"},
#  {'speaker': 'SPEAKER_03',
#   'start': 94.26096875,
#   'end': 94.27784375,
#   'text': ' you'},
#  {'speaker': 'SPEAKER_04',
#   'start': 94.27784375,
#   'end': 96.28596875000001,
#   'text': ' हम नहीं लूआ जा रहे हैं, बसेला'},
#  {'speaker': 'SPEAKER_04',
#   'start': 96.52221875000001,
#   'end': 97.68659375,
#   'text': ' Wow!'},
#  {'speaker': 'SPEAKER_04',
#   'start': 98.02409375,
#   'end': 98.51346875,
#   'text': ' 와'},
#  {'speaker': 'SPEAKER_04',
#   'start': 99.07034375,
#   'end': 101.51721875000001,
#   'text': ' કિયા મઇસાલ દઈ તૂ ને મતરતા કી બાહ્'},
#  {'speaker': 'SPEAKER_04',
#   'start': 102.12471875,
#   'end': 106.90034375,
#   'text': ' नहीं मतलब सचो दोस्त मित्र को पाद भी सुंग ले तो तुम हमें नहीं सुंग पाढा।'},
#  {'speaker': 'SPEAKER_03',
#   'start': 107.13659375,
#   'end': 116.97471875000001,
#   'text': ' हाँसू भाईया चोवीश घंटा हम तवा पात तो सुनता ही है लेकिन अब जो बसा रहा है वो पात समझ़ानक है मतलब तुन ने बिठार है? नहीं एइ आब अस्थाम था'},
#  {'speaker': 'SPEAKER_04',
#   'start': 116.97471875000001,
#   'end': 118.12221875,
#   'text': ' मैं तो नहीं बिठार सकता'},
#  {'speaker': 'SPEAKER_04',
#   'start': 118.61159375000001,
#   'end': 120.53534375000001,
#   'text': ' अरे तो रुख जा फर सेंट लगा के आ रहे हैं'},
#  {'speaker': 'SPEAKER_03',
#   'start': 122.86409375000001,
#   'end': 122.88096875000001,
#   'text': ' you'},
#  {'speaker': 'SPEAKER_02',
#   'start': 122.88096875000001,
#   'end': 126.23909375000001,
#   'text': ' एक से एक लाल आदमी देखे, मैंने ऐसे जैसे नहीं देखो'},
#  {'speaker': 'SPEAKER_02',
#   'start': 126.45846875000001,
#   'end': 132.44909375,
#   'text': ' खेरा पनी स्रक्छापने हाथ में मतो बान दाहिलू ना कोई जानो कौन भीमारी हुज्जे'},
#  {'speaker': 'SPEAKER_04',
#   'start': 139.87409375000001,
#   'end': 144.43034375000002,
#   'text': ' लेव संगे इधर ले रहा हैं जब बस आये सो बता दिगे अब'},
#  {'speaker': 'SPEAKER_01',
#   'start': 155.02784375000002,
#   'end': 155.95596875,
#   'text': ' मारे राज!'},
#  {'speaker': 'SPEAKER_01',
#   'start': 157.08659375000002,
#   'end': 160.02284375000002,
#   'text': 'เฮ้ย บ้าฮันเฮ้ย'},
#  {'speaker': 'SPEAKER_01',
#   'start': 160.27596875,
#   'end': 163.34721875,
#   'text': ' बुखार में सो मर जा रहे हैं भाईया.'},
#  {'speaker': 'SPEAKER_01',
#   'start': 163.90409375000002,
#   'end': 165.87846875000002,
#   'text': ' एवागुमान अपतो तो मोठाले'},
#  {'speaker': 'SPEAKER_01',
#   'start': 166.62096875,
#   'end': 168.59534375,
#   'text': " Avni Yüce Hulusi Seher'in..."},
#  {'speaker': 'SPEAKER_01',
#   'start': 169.40534375000001,
#   'end': 171.61596875,
#   'text': ' अरे आड़ो आई पिला रही पूरी.'},
#  {'speaker': 'SPEAKER_01',
#   'start': 172.37534375,
#   'end': 173.11784375000002,
#   'text': ' अरे राहू!'},
#  {'speaker': 'SPEAKER_01',
#   'start': 173.80971875,
#   'end': 174.18096875,
#   'text': ' 음...'},
#  {'speaker': 'SPEAKER_01',
#   'start': 174.87284375000002,
#   'end': 177.03284375,
#   'text': ' योटा ले भी बहुत.'},
#  {'speaker': 'SPEAKER_00',
#   'start': 177.87659375,
#   'end': 183.44534375,
#   'text': ' काई हो कूल रहे हो केत तो हैं सवेरे 4 बजी से नहीं उठू करे मनो नहीं'},
#  {'speaker': 'SPEAKER_00',
#   'start': 183.74909375000001,
#   'end': 186.63471875000002,
#   'text': ' सबीरे से उठ जाने वा गाँभार में डूलने'},
#  {'speaker': 'SPEAKER_03',
#   'start': 186.78659375,
#   'end': 189.13221875000002,
#   'text': ' अच्छा, डोल वेसर हो रही का है?'},
#  {'speaker': 'SPEAKER_00',
#   'start': 189.33471875,
#   'end': 192.11909375000002,
#   'text': ' डोल भी से हो रहा ही और थंड में सपर भी से है'},
#  {'speaker': 'SPEAKER_03',
#   'start': 192.35534375,
#   'end': 193.33409375000002,
#   'text': ' एबं गालान.'},
#  {'speaker': 'SPEAKER_03',
#   'start': 193.70534375000003,
#   'end': 195.89909375000002,
#   'text': 'それにパイさないんだよね?それねえぜ!'},
#  {'speaker': 'SPEAKER_03',
#   'start': 196.13534375,
#   'end': 197.41784375,
#   'text': ' मन जेसांगड़ी ने बाता'},
#  {'speaker': 'SPEAKER_03',
#   'start': 197.94096875000002,
#   'end': 198.91971875000002,
#   'text': ' 그러니까 받도는냐?'},
#  {'speaker': 'SPEAKER_03',
#   'start': 199.03784375,
#   'end': 199.88159375,
#   'text': ' सब इरेश है?'},
#  {'speaker': 'SPEAKER_03',
#   'start': 199.98284375,
#   'end': 204.99471875,
#   'text': ' सपर्व उरोठवो केतो अच्छो होते हैं सरीर हर्ष्टपुष्ट रहे थे'},
#  {'speaker': 'SPEAKER_00',
#   'start': 205.21409375000002,
#   'end': 211.71096875,
#   'text': ' हाँ वो तो हमें दिखा रहा हो कितो हॉष्ट पॉष्ट है दूद पली उड़े है डले हूँ और बुखार चड़ो है सुआलाग'},
#  {'speaker': 'SPEAKER_03',
#   'start': 211.77846875,
#   'end': 214.46159375000002,
#   'text': ' आरे तो जड़कार हो आई? लग गई थंद?'},
#  {'speaker': 'SPEAKER_03',
#   'start': 215.25471875000002,
#   'end': 218.52846875,
#   'text': ' और आज हमें बुखार चड़ा है कल, तो यह भी चड़ सका, तुटने कहा है'},
#  {'speaker': 'SPEAKER_00',
#   'start': 218.76471875000001,
#   'end': 226.96596875,
#   'text': ' हमें कब उननें चड़ सकत, कैसे ने हमें तमाई गहाँ चार वजी से उठ भी किया दोता है, ने भुनसारी से सपर भी की'},
#  {'speaker': 'SPEAKER_03',
#   'start': 226.96596875,
#   'end': 229.56471875000003,
#   'text': ' चैसे बना रही होतो बनले है'},
#  {'speaker': 'SPEAKER_03',
#   'start': 230.81346875000003,
#   'end': 232.58534375000002,
#   'text': ' मम्मी, एक कप हमें भी.'},
#  {'speaker': 'SPEAKER_04',
#   'start': 232.58534375000002,
#   'end': 232.60221875000002,
#   'text': ' you'},
#  {'speaker': 'SPEAKER_00',
#   'start': 233.22659375,
#   'end': 239.16659375,
#   'text': ' हाओ बनाये देरे मनु कम से कम जुलना तो ताली भजजी ना केते सोताई लायाते'},
#  {'speaker': 'SPEAKER_04',
#   'start': 239.16659375,
#   'end': 240.93846875000003,
#   'text': ' आरे तो बन ले आमोने चल'},
#  {'speaker': 'SPEAKER_04',
#   'start': 252.85221875000002,
#   'end': 252.86909375000002,
#   'text': ' you'},
#  {'speaker': 'SPEAKER_03',
#   'start': 252.86909375000002,
#   'end': 254.62409375000001,
#   'text': ' दद्दा पगले आ गये हो का?'},
#  {'speaker': 'SPEAKER_03',
#   'start': 255.19784375,
#   'end': 257.34096875,
#   'text': ' पागल हम नहीं बैद, पागल होगा बैद तू?'},
#  {'speaker': 'SPEAKER_03',
#   'start': 258.18471875,
#   'end': 261.52596875,
#   'text': ' बाप के मौफ़ पे पुन्दारी धर के तूने पात दो तो ये सरंब नहीं आ रही'},
#  {'speaker': 'SPEAKER_04',
#   'start': 260.39534375,
#   'end': 260.80034375,
#   'text': ' 아, 진짜?'},
#  {'speaker': 'SPEAKER_04',
#   'start': 261.62721875,
#   'end': 264.79971875,
#   'text': ' अरे तगधा भगवान कसम खा रहे हमने नहीं पादू आज'},
#  {'speaker': 'SPEAKER_04',
#   'start': 265.23846875000004,
#   'end': 267.12846875,
#   'text': ' तो मैं तो कथी नुका चु, बसाता ही रहे थे'},
#  {'speaker': 'SPEAKER_04',
#   'start': 267.55034375,
#   'end': 271.85346875,
#   'text': ' दो दिना से हाग वेने गाया हुझ जो सोभाई बासे आ रही उपर एई सूतरी के'},
#  {'speaker': 'SPEAKER_03',
#   'start': 272.27534375,
#   'end': 272.29221875,
#   'text': ' you'},
#  {'speaker': 'SPEAKER_04',
#   'start': 272.29221875,
#   'end': 272.34284375000004,
#   'text': ' you'},
#  {'speaker': 'SPEAKER_03',
#   'start': 272.34284375000004,
#   'end': 274.28346875,
#   'text': ' सूराज उंग भूल सकत'},
#  {'speaker': 'SPEAKER_03',
#   'start': 274.46909375,
#   'end': 276.24096875000004,
#   'text': ' Mungkin dupa gulsakan!'},
#  {'speaker': 'SPEAKER_03',
#   'start': 276.47721875,
#   'end': 279.24471875,
#   'text': ' लेकिन स्यामलाल टट्टी करबो नहीं भूल सकाती'},
#  {'speaker': 'SPEAKER_03',
#   'start': 279.61596875000004,
#   'end': 280.39221875000004,
#   'text': ' याद और गन?'},
#  {'speaker': 'SPEAKER_03',
#   'start': 280.79721875,
#   'end': 281.87721875,
#   'text': ' तो ही मैसे आ रही है'},
#  {'speaker': 'SPEAKER_04',
#   'start': 283.96971875,
#   'end': 284.32409375000003,
#   'text': ' you'},
#  {'speaker': 'SPEAKER_04',
#   'start': 285.10034375000004,
#   'end': 286.29846875000004,
#   'text': ' तून सप्रोक अप्सण नहीं है'},
#  {'speaker': 'SPEAKER_04',
#   'start': 287.14221875000004,
#   'end': 289.79159375,
#   'text': ' Que encima te encargará que le den esa proto'},
#  {'speaker': 'SPEAKER_04',
#   'start': 289.99409375,
#   'end': 292.47471875,
#   'text': ' जैसे तरही तरही जीना को कप सने ही सपते हैं'},
#  {'speaker': 'SPEAKER_03',
#   'start': 292.82909375,
#   'end': 294.48284375000003,
#   'text': ' कल बेटा तम्हाई चड़ी नहीं में लाई'},
#  {'speaker': 'SPEAKER_04',
#   'start': 296.13659375000003,
#   'end': 296.92971875,
#   'text': ' आ तो...'},
#  {'speaker': 'SPEAKER_04',
#   'start': 297.11534375,
#   'end': 298.17846875000004,
#   'text': ' बार्शन सप्राहुझ्ये'}]
